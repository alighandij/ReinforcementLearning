# %%
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense 
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.optimizers import Adam
import numpy as np

# %%
class PolicyGradientNetwork(keras.Model):
    def __init__(self, n_actions, fc1_dims=256, fc2_dims=256):
        super(PolicyGradientNetwork, self).__init__()
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions

        self.fc1 = Dense(self.fc1_dims, activation='relu')
        self.fc2 = Dense(self.fc2_dims, activation='relu')
        self.pi = Dense(n_actions, activation='softmax')

    def call(self, state):
        value = self.fc1(state)
        value = self.fc2(value)

        pi = self.pi(value)

        return pi

# %%
class Agent:
    def __init__(self, alpha=0.003, gamma=0.99, n_actions=4,
                 layer1_size=128, layer2_size=128):

        self.gamma = gamma
        self.lr = alpha
        self.n_actions = n_actions
        self.state_memory = []
        self.action_memory = []
        self.reward_memory = []
        self.policy = PolicyGradientNetwork(n_actions=n_actions)
        self.policy.compile(optimizer=Adam(learning_rate=self.lr))

    def choose_action(self, observation):
        state = tf.convert_to_tensor([observation],dtype=tf.float32)
        probs = self.policy(state)
        action_probs = tfp.distributions.Categorical(probs=probs)
        action = action_probs.sample()
        
        return action.numpy()[0]
    

    def store_transition(self, observation, action, reward):
        self.state_memory.append(observation)
        self.action_memory.append(action)
        self.reward_memory.append(reward)

    def learn(self):
        actions = tf.convert_to_tensor(self.action_memory, dtype=tf.float32)
        rewards = tf.convert_to_tensor(self.reward_memory)
        
        G = np.zeros_like(rewards)
        for t in range(len(rewards)):
            G_sum = 0
            discount = 1
            for k in range(t, len(rewards)):
                G_sum += rewards[k]*discount
                discount *= self.gamma
                
            G[t] = G_sum
            
        with tf.GradientTape() as tape:
            loss = 0
            for idx,(g , state) in enumerate(zip(G, self.state_memory)):
                state = tf.convert_to_tensor([observation],dtype=tf.float32)
                probs = self.policy(state)
                action_probs = tfp.distributions.Categorical(probs=probs)
                log_prob = action_probs.log_prob(actions[idx])
                loss += -g + tf.squeeze(log_prob)
                
        gradient = tape.gradient(loss, self.policy.trainable_variables)
        self.policy.optimizer.apply_gradients(zip(gradient,self.policy.trainable_variables))
        
        self.state_memory = []
        self.action_memory = []
        self.reward_memory = []

# %%
# !pip install mujoco_py==2.0.2.8
# !pip install 'gym[all]'
import gym

# %%
agent = Agent(alpha=0.001,  gamma=0.99,n_actions=2)
env = gym.make('CartPole-v0')
score_history = []

# %%
if __name__ == '__main__':
    
    num_episodes = 350

    for i in range(num_episodes):
        done = False
        score = 0
        observation = env.reset()
        while not done:
            action = agent.choose_action(observation)
            observation_, reward, done, info = env.step(action)
            agent.store_transition(observation, action, reward)
            observation = observation_
            score += reward
        score_history.append(score)

        agent.learn()
        avg_score = np.mean(score_history[-100:])
        print('episode: ', i,'score: %.1f' % score,
            'average score %.1f' % avg_score)
# Out:
# episode:  0 score: 16.0 average score 16.0
# episode:  1 score: 21.0 average score 18.5
# episode:  2 score: 34.0 average score 23.7
# episode:  3 score: 17.0 average score 22.0
# episode:  4 score: 30.0 average score 23.6
# episode:  5 score: 9.0 average score 21.2
# episode:  6 score: 17.0 average score 20.6
# episode:  7 score: 84.0 average score 28.5
# episode:  8 score: 44.0 average score 30.2
# episode:  9 score: 96.0 average score 36.8
# episode:  10 score: 69.0 average score 39.7
# episode:  11 score: 23.0 average score 38.3
# episode:  12 score: 51.0 average score 39.3
# episode:  13 score: 15.0 average score 37.6
# episode:  14 score: 28.0 average score 36.9
# episode:  15 score: 92.0 average score 40.4
# episode:  16 score: 25.0 average score 39.5
# episode:  17 score: 79.0 average score 41.7
# episode:  18 score: 47.0 average score 41.9
# episode:  19 score: 62.0 average score 43.0
# episode:  20 score: 43.0 average score 43.0
# episode:  21 score: 74.0 average score 44.4
# episode:  22 score: 36.0 average score 44.0
# episode:  23 score: 23.0 average score 43.1
# episode:  24 score: 44.0 average score 43.2
# episode:  25 score: 61.0 average score 43.8
# episode:  26 score: 81.0 average score 45.2
# episode:  27 score: 43.0 average score 45.1
# episode:  28 score: 99.0 average score 47.0
# episode:  29 score: 56.0 average score 47.3
# episode:  30 score: 43.0 average score 47.2
# episode:  31 score: 65.0 average score 47.7
# episode:  32 score: 60.0 average score 48.1
# episode:  33 score: 45.0 average score 48.0
# episode:  34 score: 56.0 average score 48.2
# episode:  35 score: 93.0 average score 49.5
# episode:  36 score: 67.0 average score 49.9
# episode:  37 score: 60.0 average score 50.2
# episode:  38 score: 53.0 average score 50.3
# episode:  39 score: 56.0 average score 50.4
# episode:  40 score: 79.0 average score 51.1
# episode:  41 score: 63.0 average score 51.4
# episode:  42 score: 51.0 average score 51.4
# episode:  43 score: 31.0 average score 50.9
# episode:  44 score: 55.0 average score 51.0
# episode:  45 score: 50.0 average score 51.0
# episode:  46 score: 59.0 average score 51.2
# episode:  47 score: 68.0 average score 51.5
# episode:  48 score: 59.0 average score 51.7
# episode:  49 score: 52.0 average score 51.7
# episode:  50 score: 112.0 average score 52.9
# episode:  51 score: 77.0 average score 53.3
# episode:  52 score: 72.0 average score 53.7
# episode:  53 score: 65.0 average score 53.9
# episode:  54 score: 45.0 average score 53.7
# episode:  55 score: 88.0 average score 54.3
# episode:  56 score: 40.0 average score 54.1
# episode:  57 score: 57.0 average score 54.1
# episode:  58 score: 58.0 average score 54.2
# episode:  59 score: 41.0 average score 54.0
# episode:  60 score: 47.0 average score 53.9
# episode:  61 score: 38.0 average score 53.6
# episode:  62 score: 47.0 average score 53.5
# episode:  63 score: 45.0 average score 53.4
# episode:  64 score: 54.0 average score 53.4
# episode:  65 score: 39.0 average score 53.2
# episode:  66 score: 51.0 average score 53.1
# episode:  67 score: 54.0 average score 53.1
# episode:  68 score: 66.0 average score 53.3
# episode:  69 score: 46.0 average score 53.2
# episode:  70 score: 83.0 average score 53.6
# episode:  71 score: 30.0 average score 53.3
# episode:  72 score: 35.0 average score 53.1
# episode:  73 score: 57.0 average score 53.1
# episode:  74 score: 51.0 average score 53.1
# episode:  75 score: 125.0 average score 54.0
# episode:  76 score: 52.0 average score 54.0
# episode:  77 score: 71.0 average score 54.2
# episode:  78 score: 55.0 average score 54.2
# episode:  79 score: 95.0 average score 54.8
# episode:  80 score: 79.0 average score 55.0
# episode:  81 score: 57.0 average score 55.1
# episode:  82 score: 111.0 average score 55.7
# episode:  83 score: 138.0 average score 56.7
# episode:  84 score: 126.0 average score 57.5
# episode:  85 score: 96.0 average score 58.0
# episode:  86 score: 200.0 average score 59.6
# episode:  87 score: 160.0 average score 60.8
# episode:  88 score: 98.0 average score 61.2
# episode:  89 score: 71.0 average score 61.3
# episode:  90 score: 195.0 average score 62.8
# episode:  91 score: 140.0 average score 63.6
# episode:  92 score: 104.0 average score 64.0
# episode:  93 score: 108.0 average score 64.5
# episode:  94 score: 71.0 average score 64.6
# episode:  95 score: 86.0 average score 64.8
# episode:  96 score: 49.0 average score 64.6
# episode:  97 score: 103.0 average score 65.0
# episode:  98 score: 71.0 average score 65.1
# episode:  99 score: 66.0 average score 65.1
# episode:  100 score: 53.0 average score 65.5
# episode:  101 score: 57.0 average score 65.8
# episode:  102 score: 45.0 average score 65.9
# episode:  103 score: 59.0 average score 66.3
# episode:  104 score: 40.0 average score 66.5
# episode:  105 score: 126.0 average score 67.6
# episode:  106 score: 40.0 average score 67.8
# episode:  107 score: 109.0 average score 68.1
# episode:  108 score: 63.0 average score 68.3
# episode:  109 score: 41.0 average score 67.7
# episode:  110 score: 42.0 average score 67.5
# episode:  111 score: 96.0 average score 68.2
# episode:  112 score: 61.0 average score 68.3
# episode:  113 score: 34.0 average score 68.5
# episode:  114 score: 39.0 average score 68.6
# episode:  115 score: 33.0 average score 68.0
# episode:  116 score: 43.0 average score 68.2
# episode:  117 score: 64.0 average score 68.0
# episode:  118 score: 44.0 average score 68.0
# episode:  119 score: 38.0 average score 67.8
# episode:  120 score: 73.0 average score 68.1
# episode:  121 score: 38.0 average score 67.7
# episode:  122 score: 82.0 average score 68.2
# episode:  123 score: 32.0 average score 68.3
# episode:  124 score: 51.0 average score 68.3
# episode:  125 score: 42.0 average score 68.1
# episode:  126 score: 34.0 average score 67.7
# episode:  127 score: 34.0 average score 67.6
# episode:  128 score: 45.0 average score 67.0
# episode:  129 score: 108.0 average score 67.6
# episode:  130 score: 52.0 average score 67.7
# episode:  131 score: 52.0 average score 67.5
# episode:  132 score: 137.0 average score 68.3
# episode:  133 score: 35.0 average score 68.2
# episode:  134 score: 40.0 average score 68.0
# episode:  135 score: 97.0 average score 68.1
# episode:  136 score: 37.0 average score 67.8
# episode:  137 score: 130.0 average score 68.5
# episode:  138 score: 44.0 average score 68.4
# episode:  139 score: 45.0 average score 68.3
# episode:  140 score: 58.0 average score 68.1
# episode:  141 score: 115.0 average score 68.6
# episode:  142 score: 42.0 average score 68.5
# episode:  143 score: 48.0 average score 68.7
# episode:  144 score: 44.0 average score 68.5
# episode:  145 score: 43.0 average score 68.5
# episode:  146 score: 45.0 average score 68.3
# episode:  147 score: 92.0 average score 68.6
# episode:  148 score: 120.0 average score 69.2
# episode:  149 score: 38.0 average score 69.0
# episode:  150 score: 46.0 average score 68.4
# episode:  151 score: 41.0 average score 68.0
# episode:  152 score: 39.0 average score 67.7
# episode:  153 score: 53.0 average score 67.6
# episode:  154 score: 60.0 average score 67.7
# episode:  155 score: 43.0 average score 67.3
# episode:  156 score: 60.0 average score 67.5
# episode:  157 score: 56.0 average score 67.5
# episode:  158 score: 38.0 average score 67.3
# episode:  159 score: 40.0 average score 67.3
# episode:  160 score: 54.0 average score 67.3
# episode:  161 score: 52.0 average score 67.5
# episode:  162 score: 40.0 average score 67.4
# episode:  163 score: 44.0 average score 67.4
# episode:  164 score: 79.0 average score 67.6
# episode:  165 score: 64.0 average score 67.9
# episode:  166 score: 35.0 average score 67.7
# episode:  167 score: 31.0 average score 67.5
# episode:  168 score: 33.0 average score 67.2
# episode:  169 score: 60.0 average score 67.3
# episode:  170 score: 36.0 average score 66.8
# episode:  171 score: 62.0 average score 67.2
# episode:  172 score: 31.0 average score 67.1
# episode:  173 score: 64.0 average score 67.2
# episode:  174 score: 44.0 average score 67.1
# episode:  175 score: 79.0 average score 66.7
# episode:  176 score: 47.0 average score 66.6
# episode:  177 score: 48.0 average score 66.4
# episode:  178 score: 59.0 average score 66.4
# episode:  179 score: 43.0 average score 65.9
# episode:  180 score: 68.0 average score 65.8
# episode:  181 score: 35.0 average score 65.6
# episode:  182 score: 43.0 average score 64.9
# episode:  183 score: 60.0 average score 64.1
# episode:  184 score: 35.0 average score 63.2
# episode:  185 score: 64.0 average score 62.9
# episode:  186 score: 37.0 average score 61.2
# episode:  187 score: 39.0 average score 60.0
# episode:  188 score: 56.0 average score 59.6
# episode:  189 score: 59.0 average score 59.5
# episode:  190 score: 31.0 average score 57.9
# episode:  191 score: 33.0 average score 56.8
# episode:  192 score: 37.0 average score 56.1
# episode:  193 score: 55.0 average score 55.6
# episode:  194 score: 30.0 average score 55.2
# episode:  195 score: 29.0 average score 54.6
# episode:  196 score: 32.0 average score 54.4
# episode:  197 score: 51.0 average score 53.9
# episode:  198 score: 30.0 average score 53.5
# episode:  199 score: 30.0 average score 53.1
# episode:  200 score: 58.0 average score 53.2
# episode:  201 score: 32.0 average score 53.0
# episode:  202 score: 65.0 average score 53.1
# episode:  203 score: 31.0 average score 52.9
# episode:  204 score: 29.0 average score 52.8
# episode:  205 score: 68.0 average score 52.2
# episode:  206 score: 76.0 average score 52.5
# episode:  207 score: 53.0 average score 52.0
# episode:  208 score: 65.0 average score 52.0
# episode:  209 score: 37.0 average score 52.0
# episode:  210 score: 40.0 average score 51.9
# episode:  211 score: 37.0 average score 51.4
# episode:  212 score: 69.0 average score 51.4
# episode:  213 score: 63.0 average score 51.7
# episode:  214 score: 30.0 average score 51.6
# episode:  215 score: 36.0 average score 51.7
# episode:  216 score: 81.0 average score 52.0
# episode:  217 score: 34.0 average score 51.7
# episode:  218 score: 34.0 average score 51.6
# episode:  219 score: 33.0 average score 51.6
# episode:  220 score: 38.0 average score 51.2
# episode:  221 score: 44.0 average score 51.3
# episode:  222 score: 35.0 average score 50.8
# episode:  223 score: 33.0 average score 50.8
# episode:  224 score: 43.0 average score 50.8
# episode:  225 score: 33.0 average score 50.7
# episode:  226 score: 36.0 average score 50.7
# episode:  227 score: 32.0 average score 50.7
# episode:  228 score: 64.0 average score 50.9
# episode:  229 score: 49.0 average score 50.3
# episode:  230 score: 44.0 average score 50.2
# episode:  231 score: 43.0 average score 50.1
# episode:  232 score: 38.0 average score 49.1
# episode:  233 score: 36.0 average score 49.1
# episode:  234 score: 46.0 average score 49.2
# episode:  235 score: 45.0 average score 48.7
# episode:  236 score: 71.0 average score 49.0
# episode:  237 score: 47.0 average score 48.2
# episode:  238 score: 47.0 average score 48.2
# episode:  239 score: 41.0 average score 48.2
# episode:  240 score: 65.0 average score 48.2
# episode:  241 score: 81.0 average score 47.9
# episode:  242 score: 32.0 average score 47.8
# episode:  243 score: 38.0 average score 47.7
# episode:  244 score: 40.0 average score 47.6
# episode:  245 score: 60.0 average score 47.8
# episode:  246 score: 57.0 average score 47.9
# episode:  247 score: 32.0 average score 47.3
# episode:  248 score: 56.0 average score 46.7
# episode:  249 score: 39.0 average score 46.7
# episode:  250 score: 41.0 average score 46.7
# episode:  251 score: 55.0 average score 46.8
# episode:  252 score: 28.0 average score 46.7
# episode:  253 score: 31.0 average score 46.5
# episode:  254 score: 56.0 average score 46.4
# episode:  255 score: 34.0 average score 46.3
# episode:  256 score: 36.0 average score 46.1
# episode:  257 score: 28.0 average score 45.8
# episode:  258 score: 30.0 average score 45.7
# episode:  259 score: 34.0 average score 45.7
# episode:  260 score: 30.0 average score 45.4
# episode:  261 score: 31.0 average score 45.2
# episode:  262 score: 42.0 average score 45.2
# episode:  263 score: 26.0 average score 45.1
# episode:  264 score: 55.0 average score 44.8
# episode:  265 score: 45.0 average score 44.6
# episode:  266 score: 34.0 average score 44.6
# episode:  267 score: 29.0 average score 44.6
# episode:  268 score: 41.0 average score 44.7
# episode:  269 score: 35.0 average score 44.4
# episode:  270 score: 26.0 average score 44.3
# episode:  271 score: 10.0 average score 43.8
# episode:  272 score: 10.0 average score 43.6
# episode:  273 score: 9.0 average score 43.1
# episode:  274 score: 9.0 average score 42.7
# episode:  275 score: 9.0 average score 42.0
# episode:  276 score: 9.0 average score 41.6
# episode:  277 score: 8.0 average score 41.2
# episode:  278 score: 9.0 average score 40.7
# episode:  279 score: 9.0 average score 40.4
# episode:  280 score: 10.0 average score 39.8
# episode:  281 score: 9.0 average score 39.5
# episode:  282 score: 10.0 average score 39.2
# episode:  283 score: 10.0 average score 38.7
# episode:  284 score: 10.0 average score 38.5
# episode:  285 score: 10.0 average score 37.9
# episode:  286 score: 10.0 average score 37.7
# episode:  287 score: 10.0 average score 37.4
# episode:  288 score: 9.0 average score 36.9
# episode:  289 score: 10.0 average score 36.4
# episode:  290 score: 10.0 average score 36.2
# episode:  291 score: 9.0 average score 36.0
# episode:  292 score: 10.0 average score 35.7
# episode:  293 score: 9.0 average score 35.2
# episode:  294 score: 10.0 average score 35.0
# episode:  295 score: 10.0 average score 34.8
# episode:  296 score: 9.0 average score 34.6
# episode:  297 score: 10.0 average score 34.2
# episode:  298 score: 9.0 average score 34.0
# episode:  299 score: 9.0 average score 33.8
# episode:  300 score: 11.0 average score 33.3
# episode:  301 score: 8.0 average score 33.1
# episode:  302 score: 9.0 average score 32.5
# episode:  303 score: 9.0 average score 32.3
# episode:  304 score: 9.0 average score 32.1
# episode:  305 score: 9.0 average score 31.5
# episode:  306 score: 10.0 average score 30.8
# episode:  307 score: 10.0 average score 30.4
# episode:  308 score: 9.0 average score 29.9
# episode:  309 score: 10.0 average score 29.6
# episode:  310 score: 10.0 average score 29.3
# episode:  311 score: 9.0 average score 29.0
# episode:  312 score: 10.0 average score 28.4
# episode:  313 score: 10.0 average score 27.9
# episode:  314 score: 8.0 average score 27.7
# episode:  315 score: 10.0 average score 27.4
# episode:  316 score: 10.0 average score 26.7
# episode:  317 score: 10.0 average score 26.4
# episode:  318 score: 9.0 average score 26.2
# episode:  319 score: 10.0 average score 26.0
# episode:  320 score: 8.0 average score 25.7
# episode:  321 score: 10.0 average score 25.3
# episode:  322 score: 10.0 average score 25.1
# episode:  323 score: 9.0 average score 24.8
# episode:  324 score: 9.0 average score 24.5
# episode:  325 score: 9.0 average score 24.3
# episode:  326 score: 10.0 average score 24.0
# episode:  327 score: 10.0 average score 23.8
# episode:  328 score: 10.0 average score 23.2
# episode:  329 score: 8.0 average score 22.8
# episode:  330 score: 10.0 average score 22.5
# episode:  331 score: 10.0 average score 22.2
# episode:  332 score: 8.0 average score 21.9
# episode:  333 score: 9.0 average score 21.6
# episode:  334 score: 10.0 average score 21.2
# episode:  335 score: 10.0 average score 20.9
# episode:  336 score: 9.0 average score 20.3
# episode:  337 score: 10.0 average score 19.9
# episode:  338 score: 11.0 average score 19.5
# episode:  339 score: 9.0 average score 19.2
# episode:  340 score: 10.0 average score 18.7
# episode:  341 score: 8.0 average score 17.9
# episode:  342 score: 11.0 average score 17.7
# episode:  343 score: 10.0 average score 17.4
# episode:  344 score: 10.0 average score 17.1
# episode:  345 score: 10.0 average score 16.6
# episode:  346 score: 8.0 average score 16.1
# episode:  347 score: 9.0 average score 15.9
# episode:  348 score: 10.0 average score 15.5
# episode:  349 score: 10.0 average score 15.2
