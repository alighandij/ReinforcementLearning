# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

# %%
class ReplayBuffer():
    def __init__(self,mem_size,input_dim):
        self.mem_size = mem_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size,*input_dim),dtype=np.float32)
        self.new_state_memory = np.zeros((self.mem_size,*input_dim),dtype=np.float32)
        self.action_memory = np.zeros(self.mem_size,dtype=np.int32)
        self.reward_memory =  np.zeros(self.mem_size,dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size,dtype=np.int32)
        
    def store_transition(self,state,action,reward,next_state,done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = next_state
        self.action_memory[index] = action 
        self.reward_memory[index] = reward 
        self.terminal_memory[index] = 1-int(done)
        self.mem_cntr +=1
        
    def sample_buffer(self,batch_size):
        max_mem = min(self.mem_cntr,self.mem_size)
        batch = np.random.choice(max_mem,batch_size,replace=False)
        
        states = self.state_memory[batch] 
        next_states = self.new_state_memory[batch] 
        actions = self.action_memory[batch] 
        rewards = self.reward_memory[batch] 
        terminals = self.terminal_memory[batch]
        return states,actions,rewards,next_states,terminals

# %%
def build_dqn(lr,n_actions,input_dims,fc1_dims,fc2_dims):
    model = keras.Sequential()
    model.add(keras.layers.Dense(fc1_dims,activation='relu'))
    model.add(keras.layers.Dense(fc2_dims,activation='relu'))
    model.add(keras.layers.Dense(n_actions,activation=None))
    model.compile(optimizer=Adam(learning_rate=lr),loss='mean_squared_error')
    
    return model

# %%
class Agent():

    def __init__(self,lr,gamma,n_actions,epsilone,batch_size,input_dims,epsilone_dec=1e-3
                ,epsilone_end=0.01,mem_size=1000000,fname='dqn_LunarLande_model.h5'):
        self.action_space = [i for i in range(n_actions)]
        self.gamma =gamma
        self.epsilone = epsilone
        self.eps_min = epsilone_end
        self.eps_dec = epsilone_dec
        self.batch_size = batch_size
        self.model_file =fname
        self.memory = ReplayBuffer(mem_size,input_dims)
        self.q_eval = build_dqn(lr,n_actions,input_dims,256,256)
        
    def store_transition(self,state,action,reward,next_state,done):
        self.memory.store_transition(state,action,reward,next_state,done)
        
    def choose_action(self,observation):
        if np.random.random() < self.epsilone:
            action = np.random.choice(self.action_space)
        else:
            state = np.array([observation])#add dimention
            actions = self.q_eval.predict([state])
            action = np.argmax(actions)
            
        return action
    
    def learn(self):
        if self.memory.mem_cntr < self.batch_size:
            return
        
        states,actions,rewards,next_states,terminals=\
        self.memory.sample_buffer(self.batch_size)
        
        q_eval =self.q_eval.predict(states)
        q_next = self.q_eval.predict(next_states)
        
        q_target = np.copy(q_eval)
        batch_index = np.arange(self.batch_size,dtype=np.int32)
        q_target[batch_index,actions]=reward+terminals*self.gamma*np.max(q_next,axis=1)
        
        self.q_eval.train_on_batch(states,q_target)
        self.epsilone = self.epsilone-self.eps_dec if self.epsilone > self.eps_min else self.eps_min
        
    def save_model(self):
        self.q_eval.save(self.model_file)
        
    def load_model(self):
        self.q_eval = load_model(self.model_file)

# %%
# !pip install mujoco_py==2.0.2.8
# !pip install 'gym[all]'
import gym

if __name__ == '__main__':
    tf.compat.v1.disable_eager_execution()
    env = gym.make('LunarLander-v2')
    lr = 0.001
    n_games = 500
    agent=Agent(gamma = 0.99,epsilone=1,lr=lr,input_dims=env.observation_space.shape,
               n_actions=env.action_space.n,mem_size=1000000,batch_size=64,epsilone_end=0.01)
    
    scores = []
    eps_history = []
    for i in range(n_games):
        done=False
        score =0
        observation = env.reset()
        while not done:
            action =agent.choose_action(observation)
            observation_,reward,done,info = env.step(action)
            score +=reward
            agent.store_transition(observation,action,reward,observation_,done)
            
            observation = observation_
            
            agent.learn()
            
        eps_history.append(agent.epsilone)
        scores.append(score)
        
        avg_score = np.mean(scores[-100:])
        print('episode: ',i,'score %.2f' % score,
             'average_score %.2f' % avg_score,
             'epsilone %.2f' % agent.epsilone)
        if i% 20 ==0:
            agent.save_model()
# Out:
# episode:  0 score -75.41 average_score -75.41 epsilone 0.99
# episode:  1 score -151.22 average_score -113.31 epsilone 0.88
# episode:  2 score -217.18 average_score -147.94 epsilone 0.82
# episode:  3 score -84.72 average_score -132.13 epsilone 0.75
# episode:  4 score -305.36 average_score -166.78 epsilone 0.67
# episode:  5 score -245.75 average_score -179.94 epsilone 0.55
# episode:  6 score -400.11 average_score -211.39 epsilone 0.46
# episode:  7 score -66.91 average_score -193.33 epsilone 0.40
# episode:  8 score -253.00 average_score -199.96 epsilone 0.30
# episode:  9 score -256.57 average_score -205.62 epsilone 0.22
# episode:  10 score -159.56 average_score -201.43 epsilone 0.04
# episode:  11 score -377.04 average_score -216.07 epsilone 0.01
# episode:  12 score -46.46 average_score -203.02 epsilone 0.01
# episode:  13 score -293.13 average_score -209.46 epsilone 0.01
# episode:  14 score -345.94 average_score -218.56 epsilone 0.01
# episode:  15 score -37.76 average_score -207.26 epsilone 0.01
# episode:  16 score -342.03 average_score -215.18 epsilone 0.01
# episode:  17 score -144.89 average_score -211.28 epsilone 0.01
# episode:  18 score -56.32 average_score -203.12 epsilone 0.01
# episode:  19 score -237.86 average_score -204.86 epsilone 0.01
# episode:  20 score -146.78 average_score -202.09 epsilone 0.01
# episode:  21 score -252.46 average_score -204.38 epsilone 0.01
# episode:  22 score -138.51 average_score -201.52 epsilone 0.01
# episode:  23 score -208.41 average_score -201.81 epsilone 0.01
# episode:  24 score -188.99 average_score -201.29 epsilone 0.01
# episode:  25 score -526.38 average_score -213.80 epsilone 0.01
# episode:  26 score -251.92 average_score -215.21 epsilone 0.01
# episode:  27 score -121.91 average_score -211.88 epsilone 0.01
# episode:  28 score -496.56 average_score -221.69 epsilone 0.01
# episode:  29 score -122.53 average_score -218.39 epsilone 0.01
# episode:  30 score -424.97 average_score -225.05 epsilone 0.01
# episode:  31 score -386.54 average_score -230.10 epsilone 0.01
# episode:  32 score -116.84 average_score -226.67 epsilone 0.01
# episode:  33 score -151.06 average_score -224.44 epsilone 0.01
# episode:  34 score -482.84 average_score -231.83 epsilone 0.01
# episode:  35 score -539.41 average_score -240.37 epsilone 0.01
# episode:  36 score -278.05 average_score -241.39 epsilone 0.01
# episode:  37 score -405.15 average_score -245.70 epsilone 0.01
# episode:  38 score -243.98 average_score -245.65 epsilone 0.01
# episode:  39 score -416.98 average_score -249.94 epsilone 0.01
# episode:  40 score -332.99 average_score -251.96 epsilone 0.01
# episode:  41 score -506.93 average_score -258.03 epsilone 0.01
# episode:  42 score -442.82 average_score -262.33 epsilone 0.01
# episode:  43 score -233.35 average_score -261.67 epsilone 0.01
# episode:  44 score -458.40 average_score -266.04 epsilone 0.01
# episode:  45 score -419.62 average_score -269.38 epsilone 0.01
# episode:  46 score -434.06 average_score -272.89 epsilone 0.01
# episode:  47 score -151.16 average_score -270.35 epsilone 0.01
# episode:  48 score -392.40 average_score -272.84 epsilone 0.01
# episode:  49 score -708.37 average_score -281.55 epsilone 0.01
# episode:  50 score -247.09 average_score -280.88 epsilone 0.01
# episode:  51 score -272.22 average_score -280.71 epsilone 0.01
# episode:  52 score -215.51 average_score -279.48 epsilone 0.01
# episode:  53 score -292.78 average_score -279.73 epsilone 0.01
# episode:  54 score -348.22 average_score -280.97 epsilone 0.01
# episode:  55 score -470.04 average_score -284.35 epsilone 0.01
# episode:  56 score -331.30 average_score -285.17 epsilone 0.01
# episode:  57 score -157.03 average_score -282.96 epsilone 0.01
# episode:  58 score -414.35 average_score -285.19 epsilone 0.01
# episode:  59 score -252.60 average_score -284.64 epsilone 0.01
# episode:  60 score -282.66 average_score -284.61 epsilone 0.01
# episode:  61 score -470.46 average_score -287.61 epsilone 0.01
# episode:  62 score -137.06 average_score -285.22 epsilone 0.01
# episode:  63 score -440.47 average_score -287.65 epsilone 0.01
# episode:  64 score -388.52 average_score -289.20 epsilone 0.01
# episode:  65 score -156.05 average_score -287.18 epsilone 0.01
# episode:  66 score -92.45 average_score -284.27 epsilone 0.01
# episode:  67 score -713.50 average_score -290.59 epsilone 0.01
# episode:  68 score -259.21 average_score -290.13 epsilone 0.01
# episode:  69 score -117.17 average_score -287.66 epsilone 0.01
# episode:  70 score -420.31 average_score -289.53 epsilone 0.01
# episode:  71 score -497.20 average_score -292.41 epsilone 0.01
# episode:  72 score -386.10 average_score -293.70 epsilone 0.01
# episode:  73 score -708.86 average_score -299.31 epsilone 0.01
# episode:  74 score -593.31 average_score -303.23 epsilone 0.01
# episode:  75 score -390.65 average_score -304.38 epsilone 0.01
# episode:  76 score -380.06 average_score -305.36 epsilone 0.01
# episode:  77 score -456.92 average_score -307.30 epsilone 0.01
# episode:  78 score -267.21 average_score -306.80 epsilone 0.01
# episode:  79 score -145.36 average_score -304.78 epsilone 0.01
# episode:  80 score -742.64 average_score -310.18 epsilone 0.01
# episode:  81 score -430.27 average_score -311.65 epsilone 0.01
# episode:  82 score -533.84 average_score -314.32 epsilone 0.01
# episode:  83 score -303.94 average_score -314.20 epsilone 0.01
# episode:  84 score -279.48 average_score -313.79 epsilone 0.01
# episode:  85 score -212.29 average_score -312.61 epsilone 0.01
# episode:  86 score -314.91 average_score -312.64 epsilone 0.01
# episode:  87 score -352.44 average_score -313.09 epsilone 0.01
# episode:  88 score -126.83 average_score -311.00 epsilone 0.01
# episode:  89 score -364.76 average_score -311.60 epsilone 0.01
# episode:  90 score -560.15 average_score -314.33 epsilone 0.01
# episode:  91 score -334.12 average_score -314.54 epsilone 0.01
# episode:  92 score -251.75 average_score -313.87 epsilone 0.01
# episode:  93 score -578.15 average_score -316.68 epsilone 0.01
# episode:  94 score -557.92 average_score -319.22 epsilone 0.01
# episode:  95 score -208.68 average_score -318.07 epsilone 0.01
# episode:  96 score -319.99 average_score -318.09 epsilone 0.01
# episode:  97 score -132.90 average_score -316.20 epsilone 0.01
# episode:  98 score -208.94 average_score -315.11 epsilone 0.01
# episode:  99 score -377.33 average_score -315.74 epsilone 0.01
# episode:  100 score -689.79 average_score -321.88 epsilone 0.01
# episode:  101 score -136.52 average_score -321.73 epsilone 0.01
# episode:  102 score -485.63 average_score -324.42 epsilone 0.01
# episode:  103 score -154.31 average_score -325.11 epsilone 0.01
# episode:  104 score -565.13 average_score -327.71 epsilone 0.01
# episode:  105 score -530.62 average_score -330.56 epsilone 0.01
# episode:  106 score -168.35 average_score -328.24 epsilone 0.01
# episode:  107 score -128.60 average_score -328.86 epsilone 0.01
# episode:  108 score -636.12 average_score -332.69 epsilone 0.01
# episode:  109 score -122.96 average_score -331.35 epsilone 0.01
# episode:  110 score -305.06 average_score -332.81 epsilone 0.01
# episode:  111 score -147.51 average_score -330.51 epsilone 0.01
# episode:  112 score -207.39 average_score -332.12 epsilone 0.01
# episode:  113 score -540.40 average_score -334.60 epsilone 0.01
# episode:  114 score -193.71 average_score -333.07 epsilone 0.01
# episode:  115 score -576.60 average_score -338.46 epsilone 0.01
# episode:  116 score -10.38 average_score -335.14 epsilone 0.01
# episode:  117 score -507.82 average_score -338.77 epsilone 0.01
# episode:  118 score -373.67 average_score -341.95 epsilone 0.01
# episode:  119 score -35.02 average_score -339.92 epsilone 0.01
# episode:  120 score -155.41 average_score -340.01 epsilone 0.01
# episode:  121 score -352.76 average_score -341.01 epsilone 0.01
# episode:  122 score -652.78 average_score -346.15 epsilone 0.01
# episode:  123 score -123.69 average_score -345.30 epsilone 0.01
# episode:  124 score -107.69 average_score -344.49 epsilone 0.01
# episode:  125 score -225.83 average_score -341.49 epsilone 0.01
# episode:  126 score -639.68 average_score -345.36 epsilone 0.01
# episode:  127 score -199.31 average_score -346.14 epsilone 0.01
# episode:  128 score -119.58 average_score -342.37 epsilone 0.01
# episode:  129 score -374.87 average_score -344.89 epsilone 0.01
# episode:  130 score -351.89 average_score -344.16 epsilone 0.01
# episode:  131 score -111.07 average_score -341.41 epsilone 0.01
# episode:  132 score -261.22 average_score -342.85 epsilone 0.01
# episode:  133 score -230.76 average_score -343.65 epsilone 0.01
# episode:  134 score -99.49 average_score -339.81 epsilone 0.01
# episode:  135 score -537.48 average_score -339.79 epsilone 0.01
# episode:  136 score -460.14 average_score -341.61 epsilone 0.01
# episode:  137 score -727.17 average_score -344.83 epsilone 0.01
# episode:  138 score -193.00 average_score -344.32 epsilone 0.01
# episode:  139 score -186.15 average_score -342.02 epsilone 0.01
# episode:  140 score -539.03 average_score -344.08 epsilone 0.01
# episode:  141 score -520.03 average_score -344.21 epsilone 0.01
# episode:  142 score -370.48 average_score -343.48 epsilone 0.01
# episode:  143 score -353.20 average_score -344.68 epsilone 0.01
# episode:  144 score -596.74 average_score -346.07 epsilone 0.01
# episode:  145 score -678.95 average_score -348.66 epsilone 0.01
# episode:  146 score -419.76 average_score -348.52 epsilone 0.01
# episode:  147 score -512.87 average_score -352.13 epsilone 0.01
# episode:  148 score -107.15 average_score -349.28 epsilone 0.01
# episode:  149 score -363.13 average_score -345.83 epsilone 0.01
# episode:  150 score -255.72 average_score -345.92 epsilone 0.01
# episode:  151 score -457.28 average_score -347.77 epsilone 0.01
# episode:  152 score -433.83 average_score -349.95 epsilone 0.01
# episode:  153 score -372.13 average_score -350.74 epsilone 0.01
# episode:  154 score -162.81 average_score -348.89 epsilone 0.01
# episode:  155 score -518.53 average_score -349.37 epsilone 0.01
# episode:  156 score -138.98 average_score -347.45 epsilone 0.01
# episode:  157 score -341.92 average_score -349.30 epsilone 0.01
# episode:  158 score -421.87 average_score -349.37 epsilone 0.01
# episode:  159 score -351.69 average_score -350.37 epsilone 0.01
# episode:  160 score -382.75 average_score -351.37 epsilone 0.01
# episode:  161 score -361.92 average_score -350.28 epsilone 0.01
# episode:  162 score -163.95 average_score -350.55 epsilone 0.01
# episode:  163 score -480.78 average_score -350.95 epsilone 0.01
# episode:  164 score -460.42 average_score -351.67 epsilone 0.01
# episode:  165 score -479.61 average_score -354.91 epsilone 0.01
# episode:  166 score -181.25 average_score -355.80 epsilone 0.01
# episode:  167 score -81.34 average_score -349.47 epsilone 0.01
# episode:  168 score -510.99 average_score -351.99 epsilone 0.01
# episode:  169 score -594.51 average_score -356.76 epsilone 0.01
# episode:  170 score -111.09 average_score -353.67 epsilone 0.01
# episode:  171 score -130.69 average_score -350.01 epsilone 0.01
# episode:  172 score -74.01 average_score -346.89 epsilone 0.01
# episode:  173 score -246.44 average_score -342.26 epsilone 0.01
# episode:  174 score -363.68 average_score -339.97 epsilone 0.01
# episode:  175 score -580.88 average_score -341.87 epsilone 0.01
# episode:  176 score -179.74 average_score -339.87 epsilone 0.01
# episode:  177 score -375.31 average_score -339.05 epsilone 0.01
# episode:  178 score -376.33 average_score -340.14 epsilone 0.01
# episode:  179 score -141.16 average_score -340.10 epsilone 0.01
# episode:  180 score -540.43 average_score -338.08 epsilone 0.01
# episode:  181 score -168.14 average_score -335.46 epsilone 0.01
# episode:  182 score -484.24 average_score -334.96 epsilone 0.01
# episode:  183 score -686.30 average_score -338.78 epsilone 0.01
# episode:  184 score -231.70 average_score -338.30 epsilone 0.01
# episode:  185 score -603.59 average_score -342.22 epsilone 0.01
# episode:  186 score -657.47 average_score -345.64 epsilone 0.01
# episode:  187 score -180.60 average_score -343.93 epsilone 0.01
# episode:  188 score -567.16 average_score -348.33 epsilone 0.01
# episode:  189 score -191.91 average_score -346.60 epsilone 0.01
# episode:  190 score -139.21 average_score -342.39 epsilone 0.01
# episode:  191 score -433.47 average_score -343.38 epsilone 0.01
# episode:  192 score -385.48 average_score -344.72 epsilone 0.01
# episode:  193 score -603.82 average_score -344.98 epsilone 0.01
# episode:  194 score -509.08 average_score -344.49 epsilone 0.01
# episode:  195 score -579.12 average_score -348.19 epsilone 0.01
# episode:  196 score -693.39 average_score -351.93 epsilone 0.01
# episode:  197 score -414.33 average_score -354.74 epsilone 0.01
# episode:  198 score -544.29 average_score -358.10 epsilone 0.01
# episode:  199 score -321.74 average_score -357.54 epsilone 0.01
# episode:  200 score -309.57 average_score -353.74 epsilone 0.01
# episode:  201 score -628.64 average_score -358.66 epsilone 0.01
# episode:  202 score -221.17 average_score -356.01 epsilone 0.01
# episode:  203 score -104.56 average_score -355.52 epsilone 0.01
# episode:  204 score -297.75 average_score -352.84 epsilone 0.01
# episode:  205 score -686.36 average_score -354.40 epsilone 0.01
# episode:  206 score -432.77 average_score -357.04 epsilone 0.01
# episode:  207 score -559.68 average_score -361.36 epsilone 0.01
# episode:  208 score -599.05 average_score -360.98 epsilone 0.01
# episode:  209 score -387.75 average_score -363.63 epsilone 0.01
# episode:  210 score -351.12 average_score -364.09 epsilone 0.01
# episode:  211 score -344.38 average_score -366.06 epsilone 0.01
# episode:  212 score -670.41 average_score -370.69 epsilone 0.01
# episode:  213 score -456.39 average_score -369.85 epsilone 0.01
# episode:  214 score -454.62 average_score -372.46 epsilone 0.01
# episode:  215 score -283.66 average_score -369.53 epsilone 0.01
# episode:  216 score -362.14 average_score -373.05 epsilone 0.01
# episode:  217 score -519.32 average_score -373.16 epsilone 0.01
# episode:  218 score -517.56 average_score -374.60 epsilone 0.01
# episode:  219 score -619.98 average_score -380.45 epsilone 0.01
# episode:  220 score -570.14 average_score -384.60 epsilone 0.01
# episode:  221 score -113.34 average_score -382.21 epsilone 0.01
# episode:  222 score -357.57 average_score -379.25 epsilone 0.01
# episode:  223 score -565.85 average_score -383.67 epsilone 0.01
# episode:  224 score -684.69 average_score -389.44 epsilone 0.01
# episode:  225 score -418.35 average_score -391.37 epsilone 0.01
# episode:  226 score -567.27 average_score -390.65 epsilone 0.01
# episode:  227 score -468.28 average_score -393.34 epsilone 0.01
# episode:  228 score -159.39 average_score -393.73 epsilone 0.01
# episode:  229 score -500.38 average_score -394.99 epsilone 0.01
# episode:  230 score -332.93 average_score -394.80 epsilone 0.01
# episode:  231 score -310.62 average_score -396.79 epsilone 0.01
# episode:  232 score -597.55 average_score -400.16 epsilone 0.01
# episode:  233 score -240.37 average_score -400.25 epsilone 0.01
# episode:  234 score -355.65 average_score -402.82 epsilone 0.01
# episode:  235 score -669.52 average_score -404.14 epsilone 0.01
# episode:  236 score -525.15 average_score -404.79 epsilone 0.01
# episode:  237 score -625.01 average_score -403.76 epsilone 0.01
# episode:  238 score -412.92 average_score -405.96 epsilone 0.01
# episode:  239 score -459.12 average_score -408.69 epsilone 0.01
# episode:  240 score -269.67 average_score -406.00 epsilone 0.01
# episode:  241 score -402.99 average_score -404.83 epsilone 0.01
# episode:  242 score -414.68 average_score -405.27 epsilone 0.01
# episode:  243 score -450.98 average_score -406.25 epsilone 0.01
# episode:  244 score -194.25 average_score -402.22 epsilone 0.01
# episode:  245 score -545.53 average_score -400.89 epsilone 0.01
# episode:  246 score -637.86 average_score -403.07 epsilone 0.01
# episode:  247 score -440.28 average_score -402.35 epsilone 0.01
# episode:  248 score -655.79 average_score -407.83 epsilone 0.01
# episode:  249 score -500.49 average_score -409.21 epsilone 0.01
# episode:  250 score -383.64 average_score -410.48 epsilone 0.01
# episode:  251 score -422.78 average_score -410.14 epsilone 0.01
# episode:  252 score -440.57 average_score -410.21 epsilone 0.01
# episode:  253 score -439.19 average_score -410.88 epsilone 0.01
# episode:  254 score -690.33 average_score -416.15 epsilone 0.01
# episode:  255 score -434.98 average_score -415.32 epsilone 0.01
# episode:  256 score -484.57 average_score -418.77 epsilone 0.01
# episode:  257 score -503.95 average_score -420.39 epsilone 0.01
# episode:  258 score -776.62 average_score -423.94 epsilone 0.01
# episode:  259 score -519.00 average_score -425.61 epsilone 0.01
# episode:  260 score -321.80 average_score -425.00 epsilone 0.01
# episode:  261 score -877.80 average_score -430.16 epsilone 0.01
# episode:  262 score -151.12 average_score -430.04 epsilone 0.01
# episode:  263 score -715.56 average_score -432.38 epsilone 0.01
# episode:  264 score -586.01 average_score -433.64 epsilone 0.01
# episode:  265 score -627.66 average_score -435.12 epsilone 0.01
# episode:  266 score -454.35 average_score -437.85 epsilone 0.01
# episode:  267 score -375.27 average_score -440.79 epsilone 0.01
# episode:  268 score -303.74 average_score -438.72 epsilone 0.01
# episode:  269 score -344.13 average_score -436.21 epsilone 0.01
# episode:  270 score -110.42 average_score -436.21 epsilone 0.01
# episode:  271 score -493.93 average_score -439.84 epsilone 0.01
# episode:  272 score -560.49 average_score -444.70 epsilone 0.01
# episode:  273 score -360.56 average_score -445.85 epsilone 0.01
# episode:  274 score -537.30 average_score -447.58 epsilone 0.01
# episode:  275 score -381.69 average_score -445.59 epsilone 0.01
# episode:  276 score -390.71 average_score -447.70 epsilone 0.01
# episode:  277 score -295.25 average_score -446.90 epsilone 0.01
# episode:  278 score -446.65 average_score -447.60 epsilone 0.01
# episode:  279 score -217.59 average_score -448.37 epsilone 0.01
# episode:  280 score -883.10 average_score -451.79 epsilone 0.01
# episode:  281 score -553.15 average_score -455.64 epsilone 0.01
# episode:  282 score -285.44 average_score -453.65 epsilone 0.01
# episode:  283 score -372.74 average_score -450.52 epsilone 0.01
# episode:  284 score -397.00 average_score -452.17 epsilone 0.01
# episode:  285 score -633.19 average_score -452.47 epsilone 0.01
# episode:  286 score -604.02 average_score -451.93 epsilone 0.01
# episode:  287 score -185.82 average_score -451.99 epsilone 0.01
# episode:  288 score -337.94 average_score -449.69 epsilone 0.01
# episode:  289 score -465.97 average_score -452.43 epsilone 0.01
# episode:  290 score -237.43 average_score -453.42 epsilone 0.01
# episode:  291 score -517.34 average_score -454.26 epsilone 0.01
# episode:  292 score -103.04 average_score -451.43 epsilone 0.01
# episode:  293 score -418.73 average_score -449.58 epsilone 0.01
# episode:  294 score -540.66 average_score -449.90 epsilone 0.01
# episode:  295 score -622.54 average_score -450.33 epsilone 0.01
# episode:  296 score -514.52 average_score -448.54 epsilone 0.01
# episode:  297 score -259.74 average_score -447.00 epsilone 0.01
# episode:  298 score -565.18 average_score -447.20 epsilone 0.01
# episode:  299 score -397.46 average_score -447.96 epsilone 0.01
# episode:  300 score -435.79 average_score -449.22 epsilone 0.01
# episode:  301 score -277.29 average_score -445.71 epsilone 0.01
# episode:  302 score -484.51 average_score -448.34 epsilone 0.01
# episode:  303 score -430.02 average_score -451.60 epsilone 0.01
# episode:  304 score -540.72 average_score -454.03 epsilone 0.01
# episode:  305 score -119.57 average_score -448.36 epsilone 0.01
# episode:  306 score -640.89 average_score -450.44 epsilone 0.01
# episode:  307 score -157.24 average_score -446.42 epsilone 0.01
# episode:  308 score -239.13 average_score -442.82 epsilone 0.01
# episode:  309 score -955.32 average_score -448.49 epsilone 0.01
# episode:  310 score -525.70 average_score -450.24 epsilone 0.01
# episode:  311 score -154.80 average_score -448.34 epsilone 0.01
# episode:  312 score -250.77 average_score -444.15 epsilone 0.01
# episode:  313 score -199.11 average_score -441.57 epsilone 0.01
# episode:  314 score -613.52 average_score -443.16 epsilone 0.01
# episode:  315 score -499.53 average_score -445.32 epsilone 0.01
# episode:  316 score -341.09 average_score -445.11 epsilone 0.01
# episode:  317 score -484.70 average_score -444.77 epsilone 0.01
# episode:  318 score -485.55 average_score -444.45 epsilone 0.01
# episode:  319 score -675.15 average_score -445.00 epsilone 0.01
# episode:  320 score -596.39 average_score -445.26 epsilone 0.01
# episode:  321 score -645.37 average_score -450.58 epsilone 0.01
# episode:  322 score -389.09 average_score -450.90 epsilone 0.01
# episode:  323 score -585.19 average_score -451.09 epsilone 0.01
# episode:  324 score -377.63 average_score -448.02 epsilone 0.01
# episode:  325 score -308.02 average_score -446.91 epsilone 0.01
# episode:  326 score -640.83 average_score -447.65 epsilone 0.01
# episode:  327 score -669.72 average_score -449.66 epsilone 0.01
# episode:  328 score -617.17 average_score -454.24 epsilone 0.01
# episode:  329 score -255.86 average_score -451.80 epsilone 0.01
# episode:  330 score -437.69 average_score -452.84 epsilone 0.01
# episode:  331 score -450.40 average_score -454.24 epsilone 0.01
# episode:  332 score -579.48 average_score -454.06 epsilone 0.01
# episode:  333 score -650.87 average_score -458.17 epsilone 0.01
# episode:  334 score -114.10 average_score -455.75 epsilone 0.01
# episode:  335 score -175.85 average_score -450.81 epsilone 0.01
# episode:  336 score -128.70 average_score -446.85 epsilone 0.01
# episode:  337 score -561.17 average_score -446.21 epsilone 0.01
# episode:  338 score -301.49 average_score -445.10 epsilone 0.01
# episode:  339 score -142.77 average_score -441.93 epsilone 0.01
# episode:  340 score -583.01 average_score -445.07 epsilone 0.01
# episode:  341 score -317.94 average_score -444.22 epsilone 0.01
# episode:  342 score -367.77 average_score -443.75 epsilone 0.01
# episode:  343 score -531.58 average_score -444.55 epsilone 0.01
# episode:  344 score -428.50 average_score -446.90 epsilone 0.01
# episode:  345 score -437.40 average_score -445.82 epsilone 0.01
# episode:  346 score -190.98 average_score -441.35 epsilone 0.01
# episode:  347 score -655.19 average_score -443.50 epsilone 0.01
# episode:  348 score -407.15 average_score -441.01 epsilone 0.01
# episode:  349 score -3090.05 average_score -466.90 epsilone 0.01
# episode:  350 score -365.21 average_score -466.72 epsilone 0.01
# episode:  351 score -520.39 average_score -467.70 epsilone 0.01
# episode:  352 score -497.01 average_score -468.26 epsilone 0.01
# episode:  353 score -608.71 average_score -469.96 epsilone 0.01
# episode:  354 score -330.26 average_score -466.36 epsilone 0.01
# episode:  355 score -458.72 average_score -466.59 epsilone 0.01
# episode:  356 score -583.43 average_score -467.58 epsilone 0.01
# episode:  357 score -350.40 average_score -466.05 epsilone 0.01
# episode:  358 score -492.10 average_score -463.20 epsilone 0.01
# episode:  359 score -588.89 average_score -463.90 epsilone 0.01
# episode:  360 score -515.25 average_score -465.83 epsilone 0.01
# episode:  361 score -507.42 average_score -462.13 epsilone 0.01
# episode:  362 score -665.73 average_score -467.28 epsilone 0.01
# episode:  363 score -485.85 average_score -464.98 epsilone 0.01
# episode:  364 score -541.66 average_score -464.54 epsilone 0.01
# episode:  365 score -120.53 average_score -459.46 epsilone 0.01
# episode:  366 score -705.60 average_score -461.98 epsilone 0.01
# episode:  367 score -477.16 average_score -463.00 epsilone 0.01
# episode:  368 score -98.92 average_score -460.95 epsilone 0.01
# episode:  369 score -331.75 average_score -460.82 epsilone 0.01
# episode:  370 score -930.59 average_score -469.03 epsilone 0.01
# episode:  371 score -621.87 average_score -470.30 epsilone 0.01
# episode:  372 score -609.26 average_score -470.79 epsilone 0.01
# episode:  373 score -359.32 average_score -470.78 epsilone 0.01
# episode:  374 score -14.29 average_score -465.55 epsilone 0.01
# episode:  375 score -467.28 average_score -466.41 epsilone 0.01
# episode:  376 score -124.10 average_score -463.74 epsilone 0.01
# episode:  377 score -348.85 average_score -464.28 epsilone 0.01
# episode:  378 score -643.39 average_score -466.24 epsilone 0.01
# episode:  379 score -581.90 average_score -469.89 epsilone 0.01
# episode:  380 score -517.75 average_score -466.23 epsilone 0.01
# episode:  381 score -135.22 average_score -462.05 epsilone 0.01
# episode:  382 score -316.38 average_score -462.36 epsilone 0.01
# episode:  383 score -219.31 average_score -460.83 epsilone 0.01
# episode:  384 score -478.95 average_score -461.65 epsilone 0.01
# episode:  385 score -532.07 average_score -460.64 epsilone 0.01
# episode:  386 score -548.82 average_score -460.09 epsilone 0.01
# episode:  387 score -523.74 average_score -463.46 epsilone 0.01
# episode:  388 score -739.45 average_score -467.48 epsilone 0.01
# episode:  389 score -646.89 average_score -469.29 epsilone 0.01
# episode:  390 score -468.42 average_score -471.60 epsilone 0.01
# episode:  391 score -344.80 average_score -469.87 epsilone 0.01
# episode:  392 score -313.96 average_score -471.98 epsilone 0.01
# episode:  393 score -290.90 average_score -470.70 epsilone 0.01
# episode:  394 score -336.90 average_score -468.67 epsilone 0.01
# episode:  395 score -282.03 average_score -465.26 epsilone 0.01
# episode:  396 score -417.02 average_score -464.29 epsilone 0.01
# episode:  397 score -299.26 average_score -464.68 epsilone 0.01
# episode:  398 score -488.55 average_score -463.92 epsilone 0.01
# episode:  399 score -486.47 average_score -464.81 epsilone 0.01
# episode:  400 score -424.75 average_score -464.69 epsilone 0.01
# episode:  401 score -397.42 average_score -465.90 epsilone 0.01
# episode:  402 score -134.69 average_score -462.40 epsilone 0.01
# episode:  403 score -272.80 average_score -460.83 epsilone 0.01
# episode:  404 score -96.46 average_score -456.38 epsilone 0.01
# episode:  405 score -417.53 average_score -459.36 epsilone 0.01
# episode:  406 score -341.55 average_score -456.37 epsilone 0.01
# episode:  407 score -743.70 average_score -462.23 epsilone 0.01
# episode:  408 score -737.55 average_score -467.22 epsilone 0.01
# episode:  409 score -691.82 average_score -464.58 epsilone 0.01
# episode:  410 score -340.38 average_score -462.73 epsilone 0.01
# episode:  411 score -332.85 average_score -464.51 epsilone 0.01
# episode:  412 score -591.55 average_score -467.92 epsilone 0.01
# episode:  413 score -713.00 average_score -473.06 epsilone 0.01
# episode:  414 score -484.64 average_score -471.77 epsilone 0.01
# episode:  415 score -197.09 average_score -468.74 epsilone 0.01
# episode:  416 score -394.82 average_score -469.28 epsilone 0.01
# episode:  417 score -495.46 average_score -469.39 epsilone 0.01
# episode:  418 score -634.05 average_score -470.87 epsilone 0.01
# episode:  419 score -493.40 average_score -469.06 epsilone 0.01
# episode:  420 score -527.37 average_score -468.37 epsilone 0.01
# episode:  421 score -662.59 average_score -468.54 epsilone 0.01
# episode:  422 score -606.57 average_score -470.71 epsilone 0.01
# episode:  423 score -442.35 average_score -469.28 epsilone 0.01
# episode:  424 score -642.83 average_score -471.94 epsilone 0.01
# episode:  425 score -131.26 average_score -470.17 epsilone 0.01
# episode:  426 score -448.17 average_score -468.24 epsilone 0.01
# episode:  427 score -464.24 average_score -466.19 epsilone 0.01
# episode:  428 score -462.33 average_score -464.64 epsilone 0.01
# episode:  429 score -558.43 average_score -467.67 epsilone 0.01
# episode:  430 score -730.67 average_score -470.59 epsilone 0.01
# episode:  431 score -452.31 average_score -470.61 epsilone 0.01
# episode:  432 score -584.15 average_score -470.66 epsilone 0.01
# episode:  433 score -857.01 average_score -472.72 epsilone 0.01
# episode:  434 score -458.88 average_score -476.17 epsilone 0.01
# episode:  435 score -412.18 average_score -478.53 epsilone 0.01
# episode:  436 score -610.84 average_score -483.35 epsilone 0.01
# episode:  437 score -498.43 average_score -482.73 epsilone 0.01
# episode:  438 score -505.95 average_score -484.77 epsilone 0.01
# episode:  439 score -657.44 average_score -489.92 epsilone 0.01
# episode:  440 score -380.22 average_score -487.89 epsilone 0.01
# episode:  441 score -227.16 average_score -486.98 epsilone 0.01
# episode:  442 score -673.02 average_score -490.04 epsilone 0.01
# episode:  443 score -258.45 average_score -487.30 epsilone 0.01
# episode:  444 score -567.56 average_score -488.69 epsilone 0.01
# episode:  445 score -463.82 average_score -488.96 epsilone 0.01
# episode:  446 score -399.10 average_score -491.04 epsilone 0.01
# episode:  447 score -614.51 average_score -490.63 epsilone 0.01
# episode:  448 score -413.88 average_score -490.70 epsilone 0.01
# episode:  449 score -668.75 average_score -466.49 epsilone 0.01
# episode:  450 score -532.43 average_score -468.16 epsilone 0.01
# episode:  451 score -539.31 average_score -468.35 epsilone 0.01
# episode:  452 score -528.62 average_score -468.66 epsilone 0.01
# episode:  453 score -287.47 average_score -465.45 epsilone 0.01
# episode:  454 score -303.73 average_score -465.19 epsilone 0.01
# episode:  455 score -442.66 average_score -465.03 epsilone 0.01
# episode:  456 score -650.84 average_score -465.70 epsilone 0.01
# episode:  457 score -542.54 average_score -467.62 epsilone 0.01
# episode:  458 score -569.58 average_score -468.40 epsilone 0.01
# episode:  459 score -639.22 average_score -468.90 epsilone 0.01
# episode:  460 score -664.35 average_score -470.39 epsilone 0.01
# episode:  461 score -390.88 average_score -469.23 epsilone 0.01
# episode:  462 score -610.71 average_score -468.68 epsilone 0.01
# episode:  463 score -401.38 average_score -467.83 epsilone 0.01
# episode:  464 score -569.33 average_score -468.11 epsilone 0.01
# episode:  465 score -402.15 average_score -470.92 epsilone 0.01
# episode:  466 score -333.04 average_score -467.20 epsilone 0.01
# episode:  467 score -756.55 average_score -469.99 epsilone 0.01
# episode:  468 score -668.64 average_score -475.69 epsilone 0.01
# episode:  469 score -356.82 average_score -475.94 epsilone 0.01
# episode:  470 score -514.87 average_score -471.78 epsilone 0.01
# episode:  471 score -505.06 average_score -470.61 epsilone 0.01
# episode:  472 score -633.08 average_score -470.85 epsilone 0.01
# episode:  473 score -510.15 average_score -472.36 epsilone 0.01
# episode:  474 score -302.17 average_score -475.24 epsilone 0.01
# episode:  475 score -636.07 average_score -476.93 epsilone 0.01
# episode:  476 score -545.23 average_score -481.14 epsilone 0.01
# episode:  477 score -399.90 average_score -481.65 epsilone 0.01
# episode:  478 score -644.88 average_score -481.66 epsilone 0.01
# episode:  479 score -701.42 average_score -482.86 epsilone 0.01
# episode:  480 score -231.92 average_score -480.00 epsilone 0.01
# episode:  481 score -576.63 average_score -484.42 epsilone 0.01
# episode:  482 score -327.10 average_score -484.52 epsilone 0.01
# episode:  483 score -525.06 average_score -487.58 epsilone 0.01
# episode:  484 score -209.91 average_score -484.89 epsilone 0.01
# episode:  485 score -494.49 average_score -484.51 epsilone 0.01
# episode:  486 score -297.86 average_score -482.00 epsilone 0.01
# episode:  487 score -558.62 average_score -482.35 epsilone 0.01
# episode:  488 score -437.97 average_score -479.34 epsilone 0.01
# episode:  489 score -411.55 average_score -476.99 epsilone 0.01
# episode:  490 score -251.74 average_score -474.82 epsilone 0.01
# episode:  491 score -360.94 average_score -474.98 epsilone 0.01
# episode:  492 score -660.37 average_score -478.44 epsilone 0.01
# episode:  493 score -644.62 average_score -481.98 epsilone 0.01
# episode:  494 score -570.00 average_score -484.31 epsilone 0.01
# episode:  495 score -190.14 average_score -483.39 epsilone 0.01
# episode:  496 score -385.27 average_score -483.08 epsilone 0.01
# episode:  497 score -591.58 average_score -486.00 epsilone 0.01
# episode:  498 score -623.98 average_score -487.35 epsilone 0.01
# episode:  499 score -411.31 average_score -486.60 epsilone 0.01
